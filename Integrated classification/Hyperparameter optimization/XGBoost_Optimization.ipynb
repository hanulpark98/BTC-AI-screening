# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split , cross_val_score
from sklearn.metrics import make_scorer, roc_auc_score, accuracy_score, f1_score, log_loss, recall_score
from tqdm import tqdm
import logging
import optuna
from optuna.samplers import TPESampler
from optuna.pruners import MedianPruner
from optuna.logging import get_logger

# %% [markdown]
# Log data preperation

# %%
# Set up logging configuration
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Create a custom file handler
file_handler = logging.FileHandler('optuna_logs_XGBoost.log')
file_handler.setLevel(logging.INFO)
file_handler.setFormatter(logging.Formatter('%(asctime)s - %(levelname)s - %(message)s'))

# Add file handler to Optuna's logger
logger = optuna.logging.get_logger('optuna')
logger.addHandler(file_handler)

# %% [markdown]
# Data preperation

# %%
# Load the dataset using Pandas
#df = pd.read_excel('../step1 (Datasets)/PHR_1.0.3b_LabResultsMVRemoved.xlsx')
#df = pd.read_excel('../step1 (Datasets)/PHR_1.0.3b_LabResultsMVRemoved_MICEimputed.xlsx')
#df = pd.read_excel('../step1 (Datasets)/PHR_1.0.2b_MICEimputed.xlsx')
df = pd.read_excel('../../step1 (Datasets)/PHR_1.0.3b_LabResultsMVRemoved_refined_MedianImputation.xlsx')

# Specify the target column name
target_name = 'Cancer Label'

# Separate features and target
X = df.drop(columns=[target_name])
y = df[target_name]

# Encode categorical variables if needed
for column in X.select_dtypes(include=['object']).columns:
    le = LabelEncoder()
    X[column] = le.fit_transform(X[column])

# %% [markdown]
# Ultiparameters

# %%
# Number of random splits for HPO
HPO_splits = 10

# Number of random splits for evaluation of HPO-adjusted model
Model_evaluation_splits = 30

# %% [markdown]
# Optuna HPO & evaluation

# %%
# Function to optimize hyperparameters using Optuna
def objective(trial, state):
    param_grid = {
        'gpu_id': 0,
        'booster': trial.suggest_categorical('booster', ['gbtree', 'gblinear', 'dart']),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.008, 0.2),
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.3, 1.0),
        'gamma': trial.suggest_float('gamma', 0.1, 1.0),
        'lambda': trial.suggest_float('lambda', 1e-3, 1.0, log=True),
        'alpha': trial.suggest_float('alpha', 1e-3, 1.0, log=True),
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'verbose':0
    }

    # Create train/test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=state)
    
    model = xgb.XGBClassifier(**param_grid)
    
    # Use cross-validation to evaluate model with recall
    recall_scorer = make_scorer(recall_score)  # Recall (sensitivity) scorer
    recall = cross_val_score(model, X_train, y_train, cv=5, scoring=recall_scorer).mean()

    return recall


model_overall_best_Hparams_model_performance_metrics = []
model_overall_best_Hparams_model_auc_roc = 0
model_overall_best_Hparams_list = []
model_overall_best_Hparams_splitIndex = 0

# Main evaluation loop for finding best Hp and overall performance
for h_split in tqdm(range(HPO_splits), desc="Hyperparameter Optimization Progress"):
    print(f"Processing split state: {h_split}")
    
    # Optimize hyperparameters for the split (state)
    study = optuna.create_study(direction='maximize', sampler=TPESampler(), pruner=MedianPruner())
    study.optimize(lambda trial: objective(trial, h_split), n_trials=100)

    # Get the best hyperparameters for the split in 100 trials
    best_params = study.best_params
    print(f"Best parameters for split state {h_split}: {best_params}")

    all_metrics = []
    
    # Evaluate the split-based optimized hyperparameters 
    for e_split in tqdm(range(Model_evaluation_splits), desc="Evaluation Progress", leave=False):
        
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=e_split)
        
        model = xgb.XGBClassifier(**best_params)
        model.fit(X_train, y_train)
        y_pred_test = model.predict_proba(X_test)[:, 1]
        y_pred_bin_test = model.predict(X_test)
        
        # Evaluate on the test set
        test_loss = log_loss(y_test, y_pred_test)
        accuracy = accuracy_score(y_test, model.predict(X_test))
        auc_roc = roc_auc_score(y_test, y_pred_test)
        f1 = f1_score(y_test, model.predict(X_test))
        sensitivity = recall_score(y_test, y_pred_bin_test) 
        
        all_metrics.append((test_loss, accuracy, sensitivity, auc_roc, f1))
        
    # Calculate average metrics
    all_metrics = np.array(all_metrics)
    avg_metrics = np.mean(all_metrics, axis=0)

    if avg_metrics[2] > model_overall_best_Hparams_model_auc_roc:
        model_overall_best_Hparams_model_auc_roc = avg_metrics[2]
        model_overall_best_Hparams_list = best_params
        model_overall_best_Hparams_model_performance_metrics = avg_metrics
        model_overall_best_Hparams_splitIndex = h_split
# Out:
# [I 2024-11-11 17:57:30,716] Trial 47 finished with value: 0.7227856090889965 and parameters: {'booster': 'dart', 'max_depth': 5, 'learning_rate': 0.17438575777437146, 'n_estimators': 252, 'min_child_weight': 10, 'subsample': 0.603616472937582, 'colsample_bytree': 0.7600706908966082, 'gamma': 0.3886445345631777, 'lambda': 0.030544878931287336, 'alpha': 0.6245300509138169}. Best is trial 46 with value: 0.7473385230380812.
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:57:30] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:57:36] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:57:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:57:47] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:57:53] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-11-11 17:57:59,023] Trial 48 finished with value: 0.7391752577319588 and parameters: {'booster': 'dart', 'max_depth': 4, 'learning_rate': 0.18209698757423268, 'n_estimators': 238, 'min_child_weight': 10, 'subsample': 0.7378348562812174, 'colsample_bytree': 0.6403658941340229, 'gamma': 0.4404622916768427, 'lambda': 0.024479908188896615, 'alpha': 0.8866757456620912}. Best is trial 46 with value: 0.7473385230380812.
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:57:59] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:58:04] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:58:09] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:58:15] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:58:20] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-11-11 17:58:26,087] Trial 49 finished with value: 0.7124973700820535 and parameters: {'booster': 'dart', 'max_depth': 4, 'learning_rate': 0.19545372016179693, 'n_estimators': 220, 'min_child_weight': 10, 'subsample': 0.7312060688950746, 'colsample_bytree': 0.6484609231761491, 'gamma': 0.4514855390118279, 'lambda': 0.0073686228526720805, 'alpha': 0.6972677259714525}. Best is trial 46 with value: 0.7473385230380812.
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:58:26] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:58:26] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:58:27] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:58:27] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:58:27] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-11-11 17:58:28,233] Trial 50 finished with value: 0.7186198190616453 and parameters: {'booster': 'gbtree', 'max_depth': 4, 'learning_rate': 0.18517211123110128, 'n_estimators': 203, 'min_child_weight': 10, 'subsample': 0.8955981485362001, 'colsample_bytree': 0.681690589883368, 'gamma': 0.5766125980096206, 'lambda': 0.02325510394609374, 'alpha': 0.04062000843458335}. Best is trial 46 with value: 0.7473385230380812.
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:58:28] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:58:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:58:40] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:58:47] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:58:53] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-11-11 17:58:59,359] Trial 51 finished with value: 0.7310330317694088 and parameters: {'booster': 'dart', 'max_depth': 3, 'learning_rate': 0.1645158961585101, 'n_estimators': 240, 'min_child_weight': 10, 'subsample': 0.5542504091967528, 'colsample_bytree': 0.5235835788363684, 'gamma': 0.4045956453479906, 'lambda': 0.013403070484617122, 'alpha': 0.45280879565335436}. Best is trial 46 with value: 0.7473385230380812.
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:58:59] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:59:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:59:14] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:59:21] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17:59:28] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-11-11 17:59:35,827] Trial 52 finished with value: 0.7309699137386912 and parameters: {'booster': 'dart', 'max_depth': 5, 'learning_rate': 0.1764067768202807, 'n_estimators': 270, 'min_child_weight': 9, 'subsample': 0.5173746147656099, 'colsample_bytree': 0.7971379412989459, 'gamma': 0.31049527601484, 'lambda': 0.009934627660777783, 'alpha': 0.9486000313450974}. Best is trial 46 with value: 0.7473385230380812.
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [17
31] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-11-11 18:19:37,506] Trial 95 finished with value: 0.7330948874395119 and parameters: {'booster': 'dart', 'max_depth': 9, 'learning_rate': 0.12154207636642005, 'n_estimators': 244, 'min_child_weight': 10, 'subsample': 0.6814352920527156, 'colsample_bytree': 0.863283945794634, 'gamma': 0.4593154772927645, 'lambda': 0.24333937327054564, 'alpha': 0.09697007122067332}. Best is trial 66 with value: 0.7474226804123711.
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [18:19:37] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [18:19:40] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [18:19:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [18:19:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [18:19:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-11-11 18:19:49,032] Trial 96 finished with value: 0.743298969072165 and parameters: {'booster': 'dart', 'max_depth': 10, 'learning_rate': 0.1610918641290428, 'n_estimators': 141, 'min_child_weight': 10, 'subsample': 0.7128812616349253, 'colsample_bytree': 0.9119944424911335, 'gamma': 0.9755766773292383, 'lambda': 0.017760662927416467, 'alpha': 0.20244852298605528}. Best is trial 66 with value: 0.7474226804123711.
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [18:19:49] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [18:19:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [18:19:53] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [18:19:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [18:19:58] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-11-11 18:20:00,461] Trial 97 finished with value: 0.7288870187250158 and parameters: {'booster': 'dart', 'max_depth': 10, 'learning_rate': 0.1606290698937689, 'n_estimators': 142, 'min_child_weight': 10, 'subsample': 0.711735427676631, 'colsample_bytree': 0.9097398809930151, 'gamma': 0.9228737236301844, 'lambda': 0.016360902800415796, 'alpha': 0.20202149187220275}. Best is trial 66 with value: 0.7474226804123711.
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [18:20:00] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [18:20:00] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [18:20:01] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [18:20:01] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [18:20:01] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-11-11 18:20:02,276] Trial 98 finished with value: 0.7371134020618557 and parameters: {'booster': 'gbtree', 'max_depth': 10, 'learning_rate': 0.14874848271836538, 'n_estimators': 164, 'min_child_weight': 10, 'subsample': 0.6392487898140197, 'colsample_bytree': 0.8897628960683037, 'gamma': 0.9843444938455959, 'lambda': 0.01079104304557306, 'alpha': 0.5630932678434907}. Best is trial 66 with value: 0.7474226804123711.
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [18:20:02] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [18:20:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [18:20:04] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [18:20:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [18:20:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-11-11 18:20:07,528] Trial 99 finished with value: 0.7267830843677677 and parameters: {'booster': 'dart', 'max_depth': 10, 'learning_rate': 0.18757778251873977, 'n_estimators': 90, 'min_child_weight': 10, 'subsample': 0.7661283172604987, 'colsample_bytree': 0.9394417952660329, 'gamma': 0.7869820867062063, 'lambda': 0.7523903513459349, 'alpha': 0.27839464351745336}. Best is trial 66 with value: 0.7474226804123711.
# Best parameters for split state 9: {'booster': 'dart', 'max_depth': 9, 'learning_rate': 0.16757526880337048, 'n_estimators': 271, 'min_child_weight': 10, 'subsample': 0.6462807491201441, 'colsample_bytree': 0.899034861491886, 'gamma': 0.5134323315817606, 'lambda': 0.33831616398436576, 'alpha': 0.11680506336726469}
# Evaluation Progress:   0%|                                                                                                                             | 0/30 [00:00<?, ?it/s]
# Evaluation Progress:   3%|███▉                                                                                                                 | 1/30 [00:22<10:38, 22.03s/it]
# Evaluation Progress:   7%|███████▊                                                                                                             | 2/30 [00:45<10:33, 22.62s/it]
# Evaluation Progress:  10%|███████████▋                                                                                                         | 3/30 [01:07<10:11, 22.64s/it]
# Evaluation Progress:  13%|███████████████▌                                                                                                     | 4/30 [01:31<10:00, 23.11s/it]
# Evaluation Progress:  17%|███████████████████▌                                                                                                 | 5/30 [01:58<10:10, 24.42s/it]
# Evaluation Progress:  20%|███████████████████████▍                                                                                             | 6/30 [03:47<21:14, 53.10s/it]
# Evaluation Progress:  23%|███████████████████████████                                                                                         | 7/30 [09:07<53:52, 140.55s/it]
# Evaluation Progress:  27%|██████████████████████████████▍                                                                                   | 8/30 [14:38<1:13:47, 201.24s/it]
# Evaluation Progress:  30%|██████████████████████████████████▏                                                                               | 9/30 [17:16<1:05:38, 187.55s/it]
# Evaluation Progress:  33%|██████████████████████████████████████▎                                                                            | 10/30 [17:38<45:27, 136.39s/it]
# Evaluation Progress:  37%|██████████████████████████████████████████▏                                                                        | 11/30 [17:58<31:55, 100.81s/it]
# Evaluation Progress:  40%|██████████████████████████████████████████████▍                                                                     | 12/30 [18:18<22:52, 76.26s/it]
# Evaluation Progress:  43%|██████████████████████████████████████████████████▎                                                                 | 13/30 [18:38<16:46, 59.18s/it]
# Evaluation Progress:  47%|██████████████████████████████████████████████████████▏                                                             | 14/30 [18:58<12:40, 47.50s/it]
# Evaluation Progress:  50%|██████████████████████████████████████████████████████████                                                          | 15/30 [19:19<09:51, 39.42s/it]
# Evaluation Progress:  53%|█████████████████████████████████████████████████████████████▊                                                      | 16/30 [19:45<08:16, 35.46s/it]
# Evaluation Progress:  57%|█████████████████████████████████████████████████████████████████▋                                                  | 17/30 [21:44<13:06, 60.47s/it]
# Evaluation Progress:  60%|█████████████████████████████████████████████████████████████████████                                              | 18/30 [27:09<28:01, 140.10s/it]
# Evaluation Progress:  63%|████████████████████████████████████████████████████████████████████████▊                                          | 19/30 [32:42<36:16, 197.88s/it]
# Evaluation Progress:  67%|████████████████████████████████████████████████████████████████████████████▋                                      | 20/30 [35:04<30:10, 181.09s/it]
# Evaluation Progress:  70%|████████████████████████████████████████████████████████████████████████████████▌                                  | 21/30 [35:25<19:58, 133.20s/it]
# Evaluation Progress:  73%|█████████████████████████████████████████████████████████████████████████████████████                               | 22/30 [35:47<13:17, 99.66s/it]
# Evaluation Progress:  77%|████████████████████████████████████████████████████████████████████████████████████████▉                           | 23/30 [36:08<08:52, 76.11s/it]
# Evaluation Progress:  80%|████████████████████████████████████████████████████████████████████████████████████████████▊                       | 24/30 [36:29<05:57, 59.64s/it]
# Evaluation Progress:  83%|████████████████████████████████████████████████████████████████████████████████████████████████▋                   | 25/30 [36:51<04:01, 48.33s/it]
# Evaluation Progress:  87%|████████████████████████████████████████████████████████████████████████████████████████████████████▌               | 26/30 [37:12<02:40, 40.11s/it]
# Evaluation Progress:  90%|████████████████████████████████████████████████████████████████████████████████████████████████████████▍           | 27/30 [37:37<01:46, 35.54s/it]
# Evaluation Progress:  93%|████████████████████████████████████████████████████████████████████████████████████████████████████████████▎       | 28/30 [41:09<02:57, 88.50s/it]
# Evaluation Progress:  97%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████▏   | 29/30 [46:25<02:36, 156.70s/it]
# Evaluation Progress: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 30/30 [51:40<00:00, 204.15s/it]
# Hyperparameter Optimization Progress: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [4:15:50<00:00, 1535.02s/it]

# %%
print(f"Best Hp is from split: {model_overall_best_Hparams_splitIndex}")
print(f"Best Hp are: {model_overall_best_Hparams_list}")
print(f"Best Hp tuned model performance on {Model_evaluation_splits} splits: {model_overall_best_Hparams_model_performance_metrics}")
# Out:
# Best Hp is from split: 9
# Best Hp are: {'booster': 'dart', 'max_depth': 9, 'learning_rate': 0.16757526880337048, 'n_estimators': 271, 'min_child_weight': 10, 'subsample': 0.6462807491201441, 'colsample_bytree': 0.899034861491886, 'gamma': 0.5134323315817606, 'lambda': 0.33831616398436576, 'alpha': 0.11680506336726469}
# Best Hp tuned model performance on 30 splits: [0.41344806 0.82947577 0.74320587 0.89839639 0.76482592]
